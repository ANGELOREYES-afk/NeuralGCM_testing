# %%
! pip install -q -U neuralgcm dinosaur gcsfs
! pip install --upgrade xarray zarr gcsfs
! pip install -q -U aiohttp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Users/angel/Library/Python/3.9/lib/python/site-packages (25.0.1)
# ERROR: Could not find a version that satisfies the requirement neuralgcm (from versions: none)
# ERROR: No matching distribution found for neuralgcm
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xarray in /Users/angel/Library/Python/3.9/lib/python/site-packages (2024.7.0)
# Requirement already satisfied: zarr in /Users/angel/Library/Python/3.9/lib/python/site-packages (2.18.2)
# Requirement already satisfied: gcsfs in /Users/angel/Library/Python/3.9/lib/python/site-packages (2025.2.0)
# Requirement already satisfied: numpy>=1.23 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from xarray) (2.0.2)
# Requirement already satisfied: packaging>=23.1 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from xarray) (24.2)
# Requirement already satisfied: pandas>=2.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from xarray) (2.2.3)
# Requirement already satisfied: asciitree in /Users/angel/Library/Python/3.9/lib/python/site-packages (from zarr) (0.3.3)
# Requirement already satisfied: numcodecs>=0.10.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from zarr) (0.12.1)
# Requirement already satisfied: fasteners in /Users/angel/Library/Python/3.9/lib/python/site-packages (from zarr) (0.19)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from gcsfs) (3.11.12)
# Requirement already satisfied: decorator>4.1.2 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from gcsfs) (5.1.1)
# Requirement already satisfied: fsspec==2025.2.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from gcsfs) (2025.2.0)
# Requirement already satisfied: google-auth>=1.2 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from gcsfs) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib in /Users/angel/Library/Python/3.9/lib/python/site-packages (from gcsfs) (1.2.1)
# Requirement already satisfied: google-cloud-storage in /Users/angel/Library/Python/3.9/lib/python/site-packages (from gcsfs) (3.0.0)
# Requirement already satisfied: requests in /Users/angel/Library/Python/3.9/lib/python/site-packages (from gcsfs) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.18.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from google-auth>=1.2->gcsfs) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from google-auth>=1.2->gcsfs) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from google-auth>=1.2->gcsfs) (4.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from pandas>=2.0->xarray) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from pandas>=2.0->xarray) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from pandas>=2.0->xarray) (2025.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from google-auth-oauthlib->gcsfs) (2.0.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from google-cloud-storage->gcsfs) (2.24.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from google-cloud-storage->gcsfs) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from google-cloud-storage->gcsfs) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from google-cloud-storage->gcsfs) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from requests->gcsfs) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from requests->gcsfs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from requests->gcsfs) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from requests->gcsfs) (2025.1.31)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (1.67.0rc1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (5.29.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (1.26.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from multidict<7.0,>=4.5->aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (4.12.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs) (0.6.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=2.0->xarray) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/angel/Library/Python/3.9/lib/python/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.2.2)

# %%
from typing import Any
import xarray
import gcsfs
import pickle as pkl
import neuralgcm as gcm
import numpy as np
import fsspec
import zarr
import google.auth

from google.cloud import storage
from dinosaur import horizontal_interpolation
from dinosaur import spherical_harmonic
from dinosaur import xarray_utils

gcs = gcsfs.GCSFileSystem(token='anon')

model_list = ['v1/deterministic_0_7_deg.pkl', 'v1/deterministic_1_4_deg.pkl', 'v1/deterministic_2_8_deg.pkl', 'v1/stochastic_1_4_deg.pkl', 'v1_precip/stochastic_precip_2_8_deg.pkl', 'v1_precip/stochastic_evap_2_8_deg']

model_name = 'v1/deterministic_2_8_deg.pkl'

with gcs.open(f'gs://neuralgcm/models/{model_name}', 'rb') as f:
  ckpt = pkl.load(f)

model = gcm.PressureLevelModel.from_checkpoint(ckpt)

# era5_path = 'gs://gcp-public-data-arco-era5/ar/full_37-1h-0p25deg-chunk-1.zarr-v3'

full_era5 = xarray.open_zarr(
    'gs://gcp-public-data-arco-era5/ar/1959-2022-full_37-1h-0p25deg-chunk-1.zarr-v2',
    storage_options={'token': 'anon'},
    chunks={'time': 48},
    consolidated=True,
)
# fs = gcsfs.GCSFileSystem(token="anon",project='public')

# store = gcs.get_mapper(era5_path)

# store = zarr.storage.FSStore(path=era5_path, fs=fs)

# full_era5 = xarray.open_zarr(store=store, consolidated=True, chunks=None)

# full_era5 = xarray.open_zarr(fs.get_mapper(era5_path))

#retry
# Initialize the storage client

# Get the bucket and blob

# era5 = xarray.open_zarr(
#     store,
#     chunks={'time': 48},
#     consolidated=True,
# )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 5
#       3 import gcsfs
#       4 import pickle as pkl
# ----> 5 import neuralgcm as gcm
#       6 import numpy as np
#       7 import fsspec
#
# ModuleNotFoundError: No module named 'neuralgcm'

# %%
demo_start_time = '2020-02-14'
demo_end_time = '2020-02-18'
data_inner_steps = 24  # process every 24th hour

#fix issue for no ice/water/cloud variable due to expectancy
if 'ciwc' in full_era5.data_vars:
    # Create the variable mapping dictionary
    vari = {
        'specific_cloud_ice_water_content': 'ciwc'
    }

    # Rename before creating sliced_era5
    full_era5 = full_era5.rename(vari)


available_vars = list(set(model.input_variables + model.forcing_variables).intersection(full_era5.data_vars))
# model.input_variables+ model.forcing_variables

sliced_era5 = (
    full_era5[available_vars]
    .pipe(
        xarray_utils.selective_temporal_shift,
        variables=model.forcing_variables,
        time_shift='24 hours',
    )
    .sel(time=slice(demo_start_time, demo_end_time, data_inner_steps))
    .compute()
)


era5_grid = spherical_harmonic.Grid(
    latitude_nodes=full_era5.sizes['latitude'],
    longitude_nodes=full_era5.sizes['longitude'],
    latitude_spacing=xarray_utils.infer_latitude_spacing(full_era5.latitude),
    longitude_offset=xarray_utils.infer_longitude_offset(full_era5.longitude),
)

# %%
regridder = horizontal_interpolation.ConservativeRegridder(
    era5_grid, model.data_coords.horizontal, skipna=True
)


eval_era5 = xarray_utils.regrid(sliced_era5, regridder)
eval_era5 = xarray_utils.fill_nan_with_nearest(eval_era5)

inner_steps = 24 # saves every half day --> * effects the index selection of time bellow
outer_steps = 4*inner_steps # 4 days

timedelta = np.timedelta64(1, 'h') * inner_steps # increment of time change over time
times = (np.arange(outer_steps) * inner_steps) # x-axis

inputs = model.inputs_from_xarray(eval_era5.isel(time=0))

# eval_era5["specific_cloud_ice_water_content"] = [{'level': 2, 'longitude': 3, 'latitude': 4}, {'level': 2, 'longitude': 3, 'latitude': 4}]

# model configuration

# vari ={
#     'specific_cloud_ice_water_content': 'ciwic'
# }
# renamed_era5 = eval_era5.rename_vars(vari)

# inputs = renamed_era5.isel(time = 0)


# model.inputs_from_xarray = [var for var in model.input_variables if var in eval_era5.data_vars]

input_forcings = model.forcings_from_xarray(eval_era5.isel(time=0))
rng_key = jax.random.key(42)  # optional for deterministic models
initial_state = model.encode(inputs, input_forcings, rng_key)


all_forcings = model.forcings_from_xarray(eval_era5.head(time=1))

# %%
inputs = model.inputs_from_xarray(eval_era5.isel(time=0))

#problem with this 
#when filtering through time = 0 I get * ValueError: expected variable specific_cloud_ice_water_content not found
#when anything other than time = 0 by itself e.g. inputs = model.inputs_from_xarray(eval_era5.isel(latitude=0, longitude=0)) 
#I get *  I get ValueError: expected variable geopotential to have dims ('level', 'longitude', 'latitude') or ('time', 'level', 'longitude', 'latitude'), but got ('time', 'level')
